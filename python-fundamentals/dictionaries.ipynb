# %% [markdown]
# ### Dictionaries
# - mutable
# - insertion order
# - key-value pairs
# - keys must be unique and immutable -- which means we can have tuples as key and cannot have lists
# - values can be of any type
